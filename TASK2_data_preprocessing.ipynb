# %%
#necessary libraries needed
import pandas as pd
import numpy as np
from scipy import stats

# %%
file=pd.read_csv("01.Data Cleaning and Preprocessing.csv") #csc file reading

# %%
file.head() #need 1st 5 rows to get a overview of data
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
type(file) #type of file csv reading through pandas read_csv function
# Out:
# pandas.core.frame.DataFrame

# %%
file.info #need file information
# Out:
# <bound method DataFrame.info of     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
file.describe() #gives some of the mathematical aspects of each column
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
file.info() #information of each column in terms of data type and non null data count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %%
file.isnull() #true where the field is null
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0          False    False     False       False     False        False
# 1          False    False     False       False     False        False
# 2          False    False     False       False     False        False
# 3          False    False     False       False     False        False
# 4          False    False     False       False     False        False
# ..           ...      ...       ...         ...       ...          ...
# 319        False    False     False       False     False        False
# 320        False    False     False       False     False        False
# 321        False    False     False       False     False        False
# 322        False    False     False       False     False        False
# 323        False    False     False       False     False        False
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
file=file.drop_duplicates()  #dropping the duplicate columns to  clean the data more effeciently
file
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 300    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 301    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
file.isnull().sum() #sum of all non null values in each column
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
file.notnull() #display true wherever the data is non-null
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0           True     True      True        True      True         True
# 1           True     True      True        True      True         True
# 2           True     True      True        True      True         True
# 3           True     True      True        True      True         True
# 4           True     True      True        True      True         True
# ..           ...      ...       ...         ...       ...          ...
# 298         True     True      True        True      True         True
# 299         True     True     False        True      True         True
# 300         True     True     False        True      True         True
# 301         True     True     False        True      True         True
# 307         True     True      True        True      True         True
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
file.isnull().sum().sum() #sum of total number of null values in the whole data
# Out:
# 352

# %%
file2=file.fillna(value=0) #filling all the null values by 0
file2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
file2.isnull().sum().sum() #after filling all null values by 0 , theres no null data left
# Out:
# 0

# %%
file3=file.drop(["Observation"],axis=1) #deleting the date time data type column
file3=file3.fillna(file3.mean()) #filling the nan values with the mean of their column
file3
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10  16.52000     121.717  1177.607      169.805        358.282
# 1      27.60  16.81000      79.022  1328.360      341.327        351.050
# 2      23.19  16.70900      79.562  1329.407      239.161        350.022
# 3      23.60  16.47800      81.011  1334.877      213.527        350.938
# 4      22.90  15.61800      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 298    20.90  15.16700      84.640  1283.706      339.440        354.803
# 299    24.98  14.33867      85.034  1278.345      368.564        357.723
# 300    21.00  14.33867      88.013  1307.722      278.842        357.438
# 301    21.40  14.33867      85.490  1255.986      273.484        361.365
# 307    20.89  14.30800      94.172  1327.832      251.120        351.263
#
#      T-lowerExt-2       UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
file3.isnull().sum().sum() # no data fields are  null now hence its the perfect file for further analysis.
# Out:
# 0

# %%
file4=file.fillna(method="bfill") #using backward filling to fill null data
file4
# Out:
# C:\Users\lenovo 2020\AppData\Local\Temp\ipykernel_16536\4097150096.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   file4=file.fillna(method="bfill") #using backward filling to fill null data
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    14.308      85.034  1278.345      368.564
# ...

# %%
file4.isnull().sum().sum() #still 2 values are null
# Out:
# 2

# %%
file5=file.fillna(method="ffill") #using forward filling to fill null data
file5
# Out:
# C:\Users\lenovo 2020\AppData\Local\Temp\ipykernel_16536\254326491.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   file5=file.fillna(method="ffill") #using forward filling to fill null data
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    15.167      85.034  1278.345      368.564
# ...

# %%
file5.isnull().sum().sum() #still 2 values are null
# Out:
# 2

# %%
file3.columns #extracting all the columns from file 3 because it contains no null values as now
# Out:
# Index(['Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow', 'ChipLevel4 ',
#        'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA', 'WhiteFlow-4 ',
#        'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ', 'SteamFlow-4 ',
#        'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ', 'WeakLiquorF ',
#        'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ', 'T-Top-Chips-4 ',
#        'SulphidityL-4 '],
#       dtype='object')

# %%
file3.describe() #need decription  of the data for quantile analysis to detect outlier
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  301.000000  301.000000  301.000000   301.000000   301.000000
# mean    20.568605   14.338670   87.271564  1235.537278   259.365993
# std      2.990751    1.480153    7.654578    99.788084    85.501080
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.450000   13.367000   82.027000  1197.775000   215.485000
# 50%     20.740000   14.338670   87.057000  1254.380000   271.792000
# 75%     23.000000   15.483000   91.957000  1288.104000   320.890000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     301.000000      301.000000  301.000000    301.000000    301.000000
# mean      356.907033      324.010783    1.490588    593.148090      6.143012
# std         8.939520        7.637741    0.103722     66.838056      0.059985
# ...

# %%
Q1=file3.quantile(0.25)
Q3=file3.quantile(0.75)
IQR=Q3-Q1
IQR      #detecting outlier using IQR
# Out:
# Y-Kappa              4.550000
# ChipRate             2.116000
# BF-CMratio           9.930000
# BlowFlow            90.329000
# ChipLevel4         105.405000
# T-upperExt-2        11.994000
# T-lowerExt-2         7.589000
# UCZAA                0.122000
# WhiteFlow-4         99.709000
# AAWhiteSt-4          0.013012
# AA-Wood-4            1.478000
# ChipMoisture-4       2.186000
# SteamFlow-4          8.789000
# Lower-HeatT-3        8.576000
# Upper-HeatT-3        7.785000
# ChipMass-4          19.118000
# WeakLiquorF        177.968000
# BlackFlow-2        280.075000
# WeakWashF          263.335000
# SteamHeatF-3         6.901000
# T-Top-Chips-4        2.029000
# SulphidityL-4        0.103594
# dtype: float64

# %%
file3=file3[~((file3<(Q1-1.5*IQR))|(file3>(Q3+1.5*IQR))).any(axis=1)]    #checking through formula
file3
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 2      23.19  16.70900      79.562  1329.407      239.161        350.022
# 6      13.49  13.70000      98.186  1243.688      116.275        346.208
# 8      22.50  14.23300      97.249  1346.900      330.325        352.687
# 10     22.60  13.87500      95.720  1351.240      383.731        347.683
# 12     26.62  15.46700      84.447  1334.255      386.971        349.392
# ..       ...       ...         ...       ...          ...            ...
# 273    23.36  14.60000      84.981  1275.416      344.211        349.158
# 275    23.49  15.64200      82.027  1283.041      291.001        349.961
# 297    20.40  14.23300      89.790  1278.006      379.458        354.290
# 300    21.00  14.33867      88.013  1307.722      278.842        357.438
# 307    20.89  14.30800      94.172  1327.832      251.120        351.263
#
#      T-lowerExt-2       UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
file3.describe() #now checking the new description of the data
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  129.000000  129.000000  129.000000   129.000000   129.000000
# mean    20.361085   14.755625   85.830346  1257.112161   256.892155
# std      3.045495    1.307410    7.092799    45.935264    70.470551
# min     12.480000   11.642000   71.679000  1084.083000    63.911000
# 25%     18.040000   13.875000   81.045000  1232.071000   211.836000
# 50%     20.400000   14.850000   84.865000  1279.221000   267.057000
# 75%     22.970000   15.800000   90.842000  1288.618000   306.545000
# max     26.620000   16.958000  105.911000  1351.240000   386.971000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     129.000000      129.000000  129.000000    129.000000    129.000000
# mean      357.680550      325.459589    1.501975    608.352481      6.142856
# std         7.433066        5.601752    0.096405     62.538407      0.003828
# ...
